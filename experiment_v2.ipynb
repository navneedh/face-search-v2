# %%
from IPython.display import clear_output
# !jupyter nbextension enable --py widgetsnbextension
# !git clone https://github.com/navneedh/face-search-v2
# %cd face-search-v2/

#Download model
from experiment import run 

#run experiment and set expNum to some integer
#parameters : num_trials = 20, learning_rate = 15, noise = 0.99, alpha = 0.99
expNum = 1
run(expNum, num_trials = 1)
# Out:
# ITERATION # 1
# Generating noise level options ...
#    Low Noise                               Medium Noise                         High Noise                            Recon.    Original
# Input integer between 1 (least noise) - 3 (most noise) for desired noise level

# %%
#Download grid of experiment data from trial expNum
from google.colab import files
files.download("/content/styleganexp/exp" + str(expNum) +"/data-"+ str(expNum) +".png")
